# %%
from random import randint
data=[randint(1,100) for var in range(1000)]
print(data)
import math
k=1+3.322*math.log10(1000) #k gives the no. of interval
print("\n No. of intervals",round(k))
size=(100-1)/k #size of class
min_lim=min(data)
print("\n Size of intervals ",round(size))
interval=[]
print(data[:round(len(data)/4)])
print("\nClass\t\tFrequency")
cls=[]
freq=[]
c_lim=min_lim
for var in range(round(k)):
    cls.append((c_lim,c_lim+size))
    r=(range(c_lim,c_lim+size))
    fi=0
    for v in data:
        if v in r:
            fi+=1
        freq.append(fi)
# Out:
# [55, 93, 25, 11, 17, 79, 37, 98, 81, 22, 57, 28, 5, 13, 57, 68, 23, 49, 43, 49, 86, 51, 32, 52, 12, 72, 74, 84, 70, 91, 39, 33, 17, 13, 44, 78, 60, 26, 46, 84, 30, 78, 19, 58, 13, 14, 56, 99, 68, 80, 21, 47, 65, 50, 91, 1, 11, 41, 87, 64, 69, 36, 33, 27, 11, 34, 42, 90, 11, 41, 31, 33, 34, 66, 3, 81, 65, 22, 47, 62, 24, 14, 54, 3, 27, 3, 19, 40, 5, 10, 84, 64, 54, 83, 52, 11, 26, 7, 31, 89, 15, 69, 11, 34, 78, 86, 38, 73, 73, 41, 13, 72, 34, 18, 41, 52, 33, 30, 77, 8, 78, 39, 21, 17, 72, 9, 90, 26, 34, 58, 71, 34, 18, 79, 43, 23, 23, 17, 22, 3, 87, 97, 32, 49, 23, 7, 80, 44, 85, 67, 15, 44, 29, 8, 8, 36, 81, 21, 5, 15, 85, 2, 15, 32, 47, 78, 5, 42, 85, 34, 98, 70, 78, 18, 86, 30, 42, 70, 77, 1, 23, 68, 37, 53, 74, 14, 44, 87, 87, 20, 24, 60, 25, 77, 17, 72, 1, 69, 45, 39, 47, 2, 2, 92, 35, 20, 34, 51, 8, 53, 79, 51, 14, 95, 14, 67, 74, 99, 89, 9, 8, 26, 100, 81, 2, 32, 48, 18, 6, 90, 89, 89, 84, 16, 20, 30, 62, 21, 33, 77, 74, 97, 69, 19, 30, 26, 68, 90, 26, 9, 30, 55, 93, 69, 35, 47
# ...
